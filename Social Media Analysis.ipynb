# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # ***DATA SOURCE***

# %%
scmd = pd.read_excel("Sosmed Analysis.xlsx")
scmd
# Out:
#        Month                Date     Profile Name    Channel Content Type  \
# 0    Januari 2019-01-01 19:22:27        Orange_id  INSTAGRAM     carousel
# 1    Januari 2019-01-02 17:54:18        Orange_id  INSTAGRAM        video
# 2    Januari 2019-01-03 14:37:55        Orange_id  INSTAGRAM     carousel
# 3    Januari 2019-01-04 17:42:28        Orange_id  INSTAGRAM     carousel
# 4    Januari 2019-01-08 14:32:41        Orange_id  INSTAGRAM     carousel
# ..       ...                 ...              ...        ...          ...
# 449    Maret 2019-03-30 22:54:42  Strawberry Spot  INSTAGRAM     carousel
# 450    Maret 2019-03-30 23:14:09  Strawberry Spot  INSTAGRAM     carousel
# 451    Maret 2019-03-31 12:48:52  Strawberry Spot  INSTAGRAM        video
# 452    Maret 2019-03-31 15:29:06  Strawberry Spot  INSTAGRAM        image
# 453    Maret 2019-03-31 18:08:15  Strawberry Spot  INSTAGRAM        image
#
#       Likes  Comments   Labels  Interactions  Insights - Reach  \
# ...

# %%
scmd.columns
# Out:
# Index(['Month', 'Date', 'Profile Name', 'Channel', 'Content Type', 'Likes',
#        'Comments', 'Labels', 'Interactions', 'Insights - Reach',
#        'Insights - Impressions', 'Insights - Saves', 'Insights - Engagement',
#        'Insights - Video Views'],
#       dtype='object')

# %%
scmd.head(5)
# Out:
#      Month                Date Profile Name    Channel Content Type  Likes  \
# 0  Januari 2019-01-01 19:22:27    Orange_id  INSTAGRAM     carousel  282.0
# 1  Januari 2019-01-02 17:54:18    Orange_id  INSTAGRAM        video  158.0
# 2  Januari 2019-01-03 14:37:55    Orange_id  INSTAGRAM     carousel  346.0
# 3  Januari 2019-01-04 17:42:28    Orange_id  INSTAGRAM     carousel  197.0
# 4  Januari 2019-01-08 14:32:41    Orange_id  INSTAGRAM     carousel  674.0
#
#    Comments   Labels  Interactions  Insights - Reach  Insights - Impressions  \
# 0       4.0  ORGANIC           286            3732.0                  7367.0
# 1       2.0  ORGANIC           160            3407.0                  4696.0
# 2      11.0  ORGANIC           357            4607.0                  8526.0
# 3       1.0  ORGANIC           198            3412.0                  6446.0
# 4      15.0  ORGANIC           689            9156.0                 15817.0
#
# ...

# %%
scmd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 454 entries, 0 to 453
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Month                   454 non-null    object
#  1   Date                    454 non-null    datetime64[ns]
#  2   Profile Name            454 non-null    object
#  3   Channel                 454 non-null    object
#  4   Content Type            453 non-null    object
#  5   Likes                   453 non-null    float64
#  6   Comments                453 non-null    float64
#  7   Labels                  454 non-null    object
#  8   Interactions            454 non-null    int64
#  9   Insights - Reach        449 non-null    float64
#  10  Insights - Impressions  449 non-null    float64
#  11  Insights - Saves        449 non-null    float64
#  12  Insights - Engagement   454 non-null    int64
#  13  Insights - Video Views  60 non-null     float64
# ...

# %%
scmd.isna().sum()
# Out:
# Month                       0
# Date                        0
# Profile Name                0
# Channel                     0
# Content Type                1
# Likes                       1
# Comments                    1
# Labels                      0
# Interactions                0
# Insights - Reach            5
# Insights - Impressions      5
# Insights - Saves            5
# Insights - Engagement       0
# Insights - Video Views    394
# dtype: int64

# %%
selected_columns = ['Month', 'Date', 'Profile Name', 'Channel', 'Content Type', 'Likes', 'Comments',
                     'Labels', 'Interactions', 'Insights - Reach', 'Insights - Impressions',
                     'Insights - Saves', 'Insights - Engagement']
empty_kol = scmd[selected_columns].isna().any(axis=1)
scmd[empty_kol]
# Out:
#        Month                Date     Profile Name    Channel Content Type  \
# 9    Januari 2019-01-17 14:20:38        Orange_id  INSTAGRAM     carousel
# 40     Maret 2019-03-02 15:12:20        Orange_id  INSTAGRAM          NaN
# 71     Maret 2019-03-30 17:38:25        Orange_id  INSTAGRAM        video
# 117  Januari 2019-01-11 12:01:59  Strawberry Spot  INSTAGRAM        image
# 125  Januari 2019-01-12 18:00:01  Strawberry Spot  INSTAGRAM        image
# 421    Maret 2019-03-26 11:18:08  Strawberry Spot  INSTAGRAM        video
#
#      Likes  Comments   Labels  Interactions  Insights - Reach  \
# 9     93.0       1.0  ORGANIC            94               NaN
# 40     NaN       NaN  ORGANIC             0               0.0
# 71    23.0       2.0  ORGANIC            25               NaN
# 117    3.0       0.0  ORGANIC             3               NaN
# 125   89.0       0.0  ORGANIC            89               NaN
# 421   14.0       0.0  ORGANIC            14               NaN
#
# ...

# %%
scmd["Channel"].unique()
# Out:
# array(['INSTAGRAM'], dtype=object)

# %%
scmd["Profile Name"].unique()
# Out:
# array(['Orange_id', 'Strawberry Spot'], dtype=object)

# %%
scmd["Likes"].mean()
# Out:
# 1022.0860927152318

# %%
scmd["Insights - Engagement"].mean()
# Out:
# 1085.0969162995596

# %%
scmd.dropna(subset=['Likes', 'Comments','Insights - Reach', 'Insights - Impressions',
                     'Insights - Saves'],inplace=True)
scmd.isna().sum()
# Out:
# Month                       0
# Date                        0
# Profile Name                0
# Channel                     0
# Content Type                0
# Likes                       0
# Comments                    0
# Labels                      0
# Interactions                0
# Insights - Reach            0
# Insights - Impressions      0
# Insights - Saves            0
# Insights - Engagement       0
# Insights - Video Views    388
# dtype: int64

# %%
organic_post = scmd[scmd["Labels"] == "ORGANIC"]
organic_post
# Out:
#        Month                Date     Profile Name    Channel Content Type  \
# 0    Januari 2019-01-01 19:22:27        Orange_id  INSTAGRAM     carousel
# 1    Januari 2019-01-02 17:54:18        Orange_id  INSTAGRAM        video
# 2    Januari 2019-01-03 14:37:55        Orange_id  INSTAGRAM     carousel
# 3    Januari 2019-01-04 17:42:28        Orange_id  INSTAGRAM     carousel
# 4    Januari 2019-01-08 14:32:41        Orange_id  INSTAGRAM     carousel
# ..       ...                 ...              ...        ...          ...
# 449    Maret 2019-03-30 22:54:42  Strawberry Spot  INSTAGRAM     carousel
# 450    Maret 2019-03-30 23:14:09  Strawberry Spot  INSTAGRAM     carousel
# 451    Maret 2019-03-31 12:48:52  Strawberry Spot  INSTAGRAM        video
# 452    Maret 2019-03-31 15:29:06  Strawberry Spot  INSTAGRAM        image
# 453    Maret 2019-03-31 18:08:15  Strawberry Spot  INSTAGRAM        image
#
#       Likes  Comments   Labels  Interactions  Insights - Reach  \
# ...

# %%
organic_post.isna().sum()
# Out:
# Month                       0
# Date                        0
# Profile Name                0
# Channel                     0
# Content Type                0
# Likes                       0
# Comments                    0
# Labels                      0
# Interactions                0
# Insights - Reach            0
# Insights - Impressions      0
# Insights - Saves            0
# Insights - Engagement       0
# Insights - Video Views    375
# dtype: int64

# %%
prom_post = scmd[scmd["Labels"] == "PROMOTED"]
prom_post
# Out:
#         Month                Date     Profile Name    Channel Content Type  \
# 8     Januari 2019-01-16 14:25:55        Orange_id  INSTAGRAM     carousel
# 11    Januari 2019-01-20 14:05:38        Orange_id  INSTAGRAM        image
# 16    Januari 2019-01-31 17:25:00        Orange_id  INSTAGRAM     carousel
# 28   Februari 2019-02-19 15:01:11        Orange_id  INSTAGRAM     carousel
# 31   Februari 2019-02-23 12:55:32        Orange_id  INSTAGRAM        video
# 34   Februari 2019-02-28 17:33:36        Orange_id  INSTAGRAM     carousel
# 56      Maret 2019-03-10 22:00:07        Orange_id  INSTAGRAM        image
# 69      Maret 2019-03-29 15:33:17        Orange_id  INSTAGRAM     carousel
# 119   Januari 2019-01-11 15:01:03  Strawberry Spot  INSTAGRAM        image
# 174   Januari 2019-01-24 19:30:01  Strawberry Spot  INSTAGRAM        image
# 195   Januari 2019-01-29 19:00:10  Strawberry Spot  INSTAGRAM        image
# ...

# %%
prom_post.isna().sum()
# Out:
# Month                      0
# Date                       0
# Profile Name               0
# Channel                    0
# Content Type               0
# Likes                      0
# Comments                   0
# Labels                     0
# Interactions               0
# Insights - Reach           0
# Insights - Impressions     0
# Insights - Saves           0
# Insights - Engagement      0
# Insights - Video Views    13
# dtype: int64

# %%
Jeruk = scmd[scmd["Profile Name"] == "Orange_id"]
Berry = scmd[scmd["Profile Name"] == "Strawberry Spot"]

# %%
Jeruk["Date"].duplicated().sum()
# Out:
# 0

# %%
Berry["Date"].duplicated().sum()
# Out:
# 0

# %%
len(Jeruk)
# Out:
# 72

# %%
len(Berry)
# Out:
# 376

# %% [markdown]
# # ***ORANGE***

# %%
pd.DataFrame({"Engagement Mean" : Jeruk.groupby("Content Type")["Insights - Engagement"].mean().sort_values(ascending=False)})
# Out:
#               Engagement Mean
# Content Type
# image              471.200000
# carousel           462.744681
# video              172.700000

# %%
pd.DataFrame({"Reach Mean" : Jeruk.groupby("Content Type")["Insights - Reach"].mean().sort_values(ascending=False)})
# Out:
#                Reach Mean
# Content Type
# image         8469.800000
# carousel      5359.829787
# video         3556.300000

# %%
pd.DataFrame({"Percentage Engagement (%)": (Jeruk.groupby("Content Type")["Insights - Engagement"].sum() / Jeruk["Insights - Engagement"].sum()) * 100}).sort_values(by="Percentage Engagement (%)", ascending=False)
# Out:
#               Percentage Engagement (%)
# Content Type
# carousel                      78.917958
# video                         12.533111
# image                          8.548931

# %%
pd.DataFrame({"Percentage Reach (%)": (Jeruk.groupby("Content Type")["Insights - Reach"].sum() / Jeruk["Insights - Reach"].sum()) * 100}).sort_values(by="Percentage Reach (%)", ascending=False)
# Out:
#               Percentage Reach (%)
# Content Type
# carousel                 68.943887
# video                    19.465936
# image                    11.590177

# %%
pd.DataFrame(Jeruk.groupby("Content Type")["Insights - Engagement"].sum().sort_values(ascending=False))
# Out:
#               Insights - Engagement
# Content Type
# carousel                      21749
# video                          3454
# image                          2356

# %%
pd.DataFrame(Jeruk.groupby("Content Type")["Insights - Reach"].sum().sort_values(ascending=False))
# Out:
#               Insights - Reach
# Content Type
# carousel              251912.0
# video                  71126.0
# image                  42349.0

# %%
pd.DataFrame(Jeruk.value_counts("Content Type").sort_values(ascending=False))
# Out:
#               count
# Content Type
# carousel         47
# video            20
# image             5

# %%
Jeruk[Jeruk["Labels"] == "ORGANIC"].sort_values(by="Insights - Engagement",ascending=False)
# Out:
#        Month                Date Profile Name    Channel Content Type  Likes  \
# 63     Maret 2019-03-20 19:25:44    Orange_id  INSTAGRAM     carousel  680.0
# 4    Januari 2019-01-08 14:32:41    Orange_id  INSTAGRAM     carousel  674.0
# 32  Februari 2019-02-26 14:19:43    Orange_id  INSTAGRAM     carousel  721.0
# 17  Februari 2019-02-03 14:45:21    Orange_id  INSTAGRAM     carousel  658.0
# 64     Maret 2019-03-21 17:45:47    Orange_id  INSTAGRAM     carousel  569.0
# ..       ...                 ...          ...        ...          ...    ...
# 13   Januari 2019-01-23 15:53:17    Orange_id  INSTAGRAM        video  115.0
# 72     Maret 2019-03-30 19:30:59    Orange_id  INSTAGRAM        video  112.0
# 35     Maret 2019-03-01 09:42:15    Orange_id  INSTAGRAM        video  118.0
# 68     Maret 2019-03-25 18:51:25    Orange_id  INSTAGRAM        image  119.0
# 66     Maret 2019-03-24 16:23:42    Orange_id  INSTAGRAM        video   90.0
#
# ...

# %%
Jeruk[Jeruk["Labels"] == "ORGANIC"].sort_values(by="Insights - Reach",ascending=False)
# Out:
#        Month                Date Profile Name    Channel Content Type  Likes  \
# 4    Januari 2019-01-08 14:32:41    Orange_id  INSTAGRAM     carousel  674.0
# 62     Maret 2019-03-20 16:04:35    Orange_id  INSTAGRAM        image  414.0
# 58     Maret 2019-03-15 15:26:08    Orange_id  INSTAGRAM     carousel  588.0
# 63     Maret 2019-03-20 19:25:44    Orange_id  INSTAGRAM     carousel  680.0
# 64     Maret 2019-03-21 17:45:47    Orange_id  INSTAGRAM     carousel  569.0
# ..       ...                 ...          ...        ...          ...    ...
# 51     Maret 2019-03-07 17:17:13    Orange_id  INSTAGRAM     carousel  135.0
# 19  Februari 2019-02-08 15:41:50    Orange_id  INSTAGRAM     carousel  168.0
# 13   Januari 2019-01-23 15:53:17    Orange_id  INSTAGRAM        video  115.0
# 72     Maret 2019-03-30 19:30:59    Orange_id  INSTAGRAM        video  112.0
# 66     Maret 2019-03-24 16:23:42    Orange_id  INSTAGRAM        video   90.0
#
# ...

# %%
Jeruk[Jeruk["Month"] == "Januari"].sort_values(by="Date",ascending=False)
# Out:
#       Month                Date Profile Name    Channel Content Type   Likes  \
# 16  Januari 2019-01-31 17:25:00    Orange_id  INSTAGRAM     carousel  1078.0
# 15  Januari 2019-01-29 18:14:55    Orange_id  INSTAGRAM     carousel   178.0
# 14  Januari 2019-01-24 17:30:52    Orange_id  INSTAGRAM     carousel   277.0
# 13  Januari 2019-01-23 15:53:17    Orange_id  INSTAGRAM        video   115.0
# 12  Januari 2019-01-22 17:37:18    Orange_id  INSTAGRAM        video   140.0
# 11  Januari 2019-01-20 14:05:38    Orange_id  INSTAGRAM        image   673.0
# 10  Januari 2019-01-17 15:37:50    Orange_id  INSTAGRAM     carousel   388.0
# 8   Januari 2019-01-16 14:25:55    Orange_id  INSTAGRAM     carousel   871.0
# 7   Januari 2019-01-15 19:32:43    Orange_id  INSTAGRAM     carousel   317.0
# 6   Januari 2019-01-12 14:18:00    Orange_id  INSTAGRAM     carousel   505.0
# 5   Januari 2019-01-10 18:18:03    Orange_id  INSTAGRAM        video   181.0
# ...

# %%
Jeruk[Jeruk["Month"] == "Februari"].sort_values(by="Date",ascending=False)
# Out:
#        Month                Date Profile Name    Channel Content Type  Likes  \
# 34  Februari 2019-02-28 17:33:36    Orange_id  INSTAGRAM     carousel  865.0
# 33  Februari 2019-02-28 11:34:40    Orange_id  INSTAGRAM        video  187.0
# 32  Februari 2019-02-26 14:19:43    Orange_id  INSTAGRAM     carousel  721.0
# 31  Februari 2019-02-23 12:55:32    Orange_id  INSTAGRAM        video  281.0
# 30  Februari 2019-02-22 14:28:33    Orange_id  INSTAGRAM        video  227.0
# 29  Februari 2019-02-20 14:54:20    Orange_id  INSTAGRAM        video  179.0
# 28  Februari 2019-02-19 15:01:11    Orange_id  INSTAGRAM     carousel  817.0
# 27  Februari 2019-02-14 19:19:33    Orange_id  INSTAGRAM     carousel  415.0
# 26  Februari 2019-02-13 15:19:36    Orange_id  INSTAGRAM     carousel  303.0
# 25  Februari 2019-02-12 17:02:52    Orange_id  INSTAGRAM        video  171.0
# 24  Februari 2019-02-11 19:39:34    Orange_id  INSTAGRAM     carousel  517.0
# ...

# %%
Jeruk[Jeruk["Month"] == "Maret"].sort_values(by="Date",ascending=False)
# Out:
#     Month                Date Profile Name    Channel Content Type  Likes  \
# 74  Maret 2019-03-31 22:01:26    Orange_id  INSTAGRAM     carousel  362.0
# 73  Maret 2019-03-31 13:39:03    Orange_id  INSTAGRAM     carousel  231.0
# 72  Maret 2019-03-30 19:30:59    Orange_id  INSTAGRAM        video  112.0
# 70  Maret 2019-03-29 19:15:30    Orange_id  INSTAGRAM        image  138.0
# 69  Maret 2019-03-29 15:33:17    Orange_id  INSTAGRAM     carousel  945.0
# 68  Maret 2019-03-25 18:51:25    Orange_id  INSTAGRAM        image  119.0
# 67  Maret 2019-03-24 21:59:37    Orange_id  INSTAGRAM     carousel  367.0
# 66  Maret 2019-03-24 16:23:42    Orange_id  INSTAGRAM        video   90.0
# 65  Maret 2019-03-24 11:56:31    Orange_id  INSTAGRAM     carousel  413.0
# 64  Maret 2019-03-21 17:45:47    Orange_id  INSTAGRAM     carousel  569.0
# 63  Maret 2019-03-20 19:25:44    Orange_id  INSTAGRAM     carousel  680.0
# 62  Maret 2019-03-20 16:04:35    Orange_id  INSTAGRAM        image  414.0
# ...

# %%
Jeruk[Jeruk["Labels"] == "PROMOTED"].sort_values(by="Insights - Reach",ascending=False)
# Out:
#        Month                Date Profile Name    Channel Content Type   Likes  \
# 11   Januari 2019-01-20 14:05:38    Orange_id  INSTAGRAM        image   673.0
# 56     Maret 2019-03-10 22:00:07    Orange_id  INSTAGRAM        image   570.0
# 8    Januari 2019-01-16 14:25:55    Orange_id  INSTAGRAM     carousel   871.0
# 28  Februari 2019-02-19 15:01:11    Orange_id  INSTAGRAM     carousel   817.0
# 34  Februari 2019-02-28 17:33:36    Orange_id  INSTAGRAM     carousel   865.0
# 16   Januari 2019-01-31 17:25:00    Orange_id  INSTAGRAM     carousel  1078.0
# 69     Maret 2019-03-29 15:33:17    Orange_id  INSTAGRAM     carousel   945.0
# 31  Februari 2019-02-23 12:55:32    Orange_id  INSTAGRAM        video   281.0
#
#     Comments    Labels  Interactions  Insights - Reach  \
# 11      18.0  PROMOTED           691           14393.0
# 56     115.0  PROMOTED           685           13506.0
# 8       69.0  PROMOTED           940           12128.0
# ...

# %%
pd.DataFrame(Jeruk[Jeruk["Labels"] == "PROMOTED"].groupby("Content Type")["Insights - Reach"].mean().sort_values(ascending=False))
# Out:
#               Insights - Reach
# Content Type
# image                  13949.5
# carousel               10693.0
# video                   6198.0

# %%
Jeruk[Jeruk["Labels"] == "PROMOTED"].sort_values(by="Insights - Engagement",ascending=False)
# Out:
#        Month                Date Profile Name    Channel Content Type   Likes  \
# 8    Januari 2019-01-16 14:25:55    Orange_id  INSTAGRAM     carousel   871.0
# 16   Januari 2019-01-31 17:25:00    Orange_id  INSTAGRAM     carousel  1078.0
# 28  Februari 2019-02-19 15:01:11    Orange_id  INSTAGRAM     carousel   817.0
# 69     Maret 2019-03-29 15:33:17    Orange_id  INSTAGRAM     carousel   945.0
# 34  Februari 2019-02-28 17:33:36    Orange_id  INSTAGRAM     carousel   865.0
# 11   Januari 2019-01-20 14:05:38    Orange_id  INSTAGRAM        image   673.0
# 56     Maret 2019-03-10 22:00:07    Orange_id  INSTAGRAM        image   570.0
# 31  Februari 2019-02-23 12:55:32    Orange_id  INSTAGRAM        video   281.0
#
#     Comments    Labels  Interactions  Insights - Reach  \
# 8       69.0  PROMOTED           940           12128.0
# 16      42.0  PROMOTED          1120           10051.0
# 28     134.0  PROMOTED           951           11956.0
# ...

# %%
pd.DataFrame({"Reach vs Impressions (%)": (Jeruk[Jeruk["Labels"] == "PROMOTED"].groupby("Content Type")["Insights - Reach"].sum() / Jeruk[Jeruk["Labels"] == "PROMOTED"].groupby("Content Type")["Insights - Impressions"].sum()) * 100}).sort_values(by="Reach vs Impressions (%)", ascending=False)
# Out:
#               Reach vs Impressions (%)
# Content Type
# video                        75.557723
# image                        70.263940
# carousel                     54.898397

# %%
Jeruk[Jeruk["Labels"] == "ORGANIC"].sort_values(by="Insights - Saves",ascending=False)
# Out:
#        Month                Date Profile Name    Channel Content Type  Likes  \
# 63     Maret 2019-03-20 19:25:44    Orange_id  INSTAGRAM     carousel  680.0
# 4    Januari 2019-01-08 14:32:41    Orange_id  INSTAGRAM     carousel  674.0
# 64     Maret 2019-03-21 17:45:47    Orange_id  INSTAGRAM     carousel  569.0
# 7    Januari 2019-01-15 19:32:43    Orange_id  INSTAGRAM     carousel  317.0
# 17  Februari 2019-02-03 14:45:21    Orange_id  INSTAGRAM     carousel  658.0
# ..       ...                 ...          ...        ...          ...    ...
# 49     Maret 2019-03-05 14:58:41    Orange_id  INSTAGRAM     carousel  293.0
# 22  Februari 2019-02-10 15:34:53    Orange_id  INSTAGRAM     carousel  299.0
# 39     Maret 2019-03-02 10:51:00    Orange_id  INSTAGRAM        video  132.0
# 68     Maret 2019-03-25 18:51:25    Orange_id  INSTAGRAM        image  119.0
# 46     Maret 2019-03-03 14:18:56    Orange_id  INSTAGRAM     carousel  194.0
#
# ...

# %%
Jeruk[Jeruk["Labels"] == "PROMOTED"].sort_values(by="Insights - Saves",ascending=False)
# Out:
#        Month                Date Profile Name    Channel Content Type   Likes  \
# 8    Januari 2019-01-16 14:25:55    Orange_id  INSTAGRAM     carousel   871.0
# 11   Januari 2019-01-20 14:05:38    Orange_id  INSTAGRAM        image   673.0
# 28  Februari 2019-02-19 15:01:11    Orange_id  INSTAGRAM     carousel   817.0
# 16   Januari 2019-01-31 17:25:00    Orange_id  INSTAGRAM     carousel  1078.0
# 34  Februari 2019-02-28 17:33:36    Orange_id  INSTAGRAM     carousel   865.0
# 31  Februari 2019-02-23 12:55:32    Orange_id  INSTAGRAM        video   281.0
# 69     Maret 2019-03-29 15:33:17    Orange_id  INSTAGRAM     carousel   945.0
# 56     Maret 2019-03-10 22:00:07    Orange_id  INSTAGRAM        image   570.0
#
#     Comments    Labels  Interactions  Insights - Reach  \
# 8       69.0  PROMOTED           940           12128.0
# 11      18.0  PROMOTED           691           14393.0
# 28     134.0  PROMOTED           951           11956.0
# ...

# %%
Jeruk[Jeruk["Labels"] == "PROMOTED"].sort_values(by="Insights - Engagement",ascending=False)
# Out:
#        Month                Date Profile Name    Channel Content Type   Likes  \
# 8    Januari 2019-01-16 14:25:55    Orange_id  INSTAGRAM     carousel   871.0
# 16   Januari 2019-01-31 17:25:00    Orange_id  INSTAGRAM     carousel  1078.0
# 28  Februari 2019-02-19 15:01:11    Orange_id  INSTAGRAM     carousel   817.0
# 69     Maret 2019-03-29 15:33:17    Orange_id  INSTAGRAM     carousel   945.0
# 34  Februari 2019-02-28 17:33:36    Orange_id  INSTAGRAM     carousel   865.0
# 11   Januari 2019-01-20 14:05:38    Orange_id  INSTAGRAM        image   673.0
# 56     Maret 2019-03-10 22:00:07    Orange_id  INSTAGRAM        image   570.0
# 31  Februari 2019-02-23 12:55:32    Orange_id  INSTAGRAM        video   281.0
#
#     Comments    Labels  Interactions  Insights - Reach  \
# 8       69.0  PROMOTED           940           12128.0
# 16      42.0  PROMOTED          1120           10051.0
# 28     134.0  PROMOTED           951           11956.0
# ...

# %%
pd.DataFrame({"Saves Percentage (%)": (Jeruk.groupby("Content Type")["Insights - Saves"].sum()/Jeruk.groupby("Content Type")["Insights - Engagement"].sum()) *100}).sort_values(by="Saves Percentage (%)",ascending=False)
# Out:
#               Saves Percentage (%)
# Content Type
# image                    11.842105
# carousel                  6.749736
# video                     5.037638

# %% [markdown]
# # ***STRAWBERRY***

# %%
pd.DataFrame({"Engagement Mean" : Berry.groupby("Content Type")["Insights - Engagement"].mean().sort_values(ascending=False)})
# Out:
#               Engagement Mean
# Content Type
# image              1330.29375
# carousel           1015.25000
# video               572.80000

# %%
pd.DataFrame({"Reach Mean" : Berry.groupby("Content Type")["Insights - Reach"].mean().sort_values(ascending=False)})
# Out:
#                Reach Mean
# Content Type
# image         18736.86875
# video         11015.25000
# carousel      10494.43750

# %%
pd.DataFrame({"Percentage Engagement (%)": (Berry.groupby("Content Type")["Insights - Engagement"].sum() / Berry["Insights - Engagement"].sum()) * 100}).sort_values(by="Percentage Engagement (%)", ascending=False)
# Out:
#               Percentage Engagement (%)
# Content Type
# image                         91.576638
# video                          4.928902
# carousel                       3.494461

# %%
pd.DataFrame({"Percentage Reach (%)": (Berry.groupby("Content Type")["Insights - Reach"].sum() / Berry["Insights - Reach"].sum()) * 100}).sort_values(by="Percentage Reach (%)", ascending=False)
# Out:
#               Percentage Reach (%)
# Content Type
# image                    90.786014
# video                     6.671543
# carousel                  2.542442

# %%
pd.DataFrame(Berry.groupby("Content Type")["Insights - Engagement"].sum().sort_values(ascending=False))
# Out:
#               Insights - Engagement
# Content Type
# image                        425694
# video                         22912
# carousel                      16244

# %%
pd.DataFrame(Berry.groupby("Content Type")["Insights - Reach"].sum().sort_values(ascending=False))
# Out:
#               Insights - Reach
# Content Type
# image                5995798.0
# video                 440610.0
# carousel              167911.0

# %%
pd.DataFrame(Berry.value_counts("Content Type").sort_values(ascending=False))
# Out:
#               count
# Content Type
# image           320
# video            40
# carousel         16

# %%
Berry[Berry["Labels"] == "ORGANIC"].sort_values(by="Insights - Engagement",ascending=False)
# Out:
#         Month                Date     Profile Name    Channel Content Type  \
# 336     Maret 2019-03-06 18:07:42  Strawberry Spot  INSTAGRAM        image
# 203   Januari 2019-01-31 19:00:17  Strawberry Spot  INSTAGRAM        image
# 436     Maret 2019-03-28 16:40:40  Strawberry Spot  INSTAGRAM        image
# 231  Februari 2019-02-07 16:09:17  Strawberry Spot  INSTAGRAM        image
# 311  Februari 2019-02-28 16:00:41  Strawberry Spot  INSTAGRAM        image
# ..        ...                 ...              ...        ...          ...
# 399     Maret 2019-03-21 18:51:19  Strawberry Spot  INSTAGRAM        video
# 234  Februari 2019-02-08 14:15:37  Strawberry Spot  INSTAGRAM        video
# 360     Maret 2019-03-12 16:12:24  Strawberry Spot  INSTAGRAM        video
# 442     Maret 2019-03-29 16:00:42  Strawberry Spot  INSTAGRAM        video
# 126   Januari 2019-01-12 19:46:30  Strawberry Spot  INSTAGRAM        video
#
#       Likes  Comments   Labels  Interactions  Insights - Reach  \
# ...

# %%
Berry[Berry["Labels"] == "ORGANIC"].sort_values(by="Insights - Reach",ascending=False)
# Out:
#         Month                Date     Profile Name    Channel Content Type  \
# 203   Januari 2019-01-31 19:00:17  Strawberry Spot  INSTAGRAM        image
# 280  Februari 2019-02-19 11:03:04  Strawberry Spot  INSTAGRAM        video
# 199   Januari 2019-01-30 19:00:32  Strawberry Spot  INSTAGRAM        image
# 210  Februari 2019-02-02 18:00:37  Strawberry Spot  INSTAGRAM        image
# 278  Februari 2019-02-18 16:45:04  Strawberry Spot  INSTAGRAM        image
# ..        ...                 ...              ...        ...          ...
# 438     Maret 2019-03-28 18:58:22  Strawberry Spot  INSTAGRAM     carousel
# 388     Maret 2019-03-19 18:00:47  Strawberry Spot  INSTAGRAM        image
# 360     Maret 2019-03-12 16:12:24  Strawberry Spot  INSTAGRAM        video
# 442     Maret 2019-03-29 16:00:42  Strawberry Spot  INSTAGRAM        video
# 126   Januari 2019-01-12 19:46:30  Strawberry Spot  INSTAGRAM        video
#
#       Likes  Comments   Labels  Interactions  Insights - Reach  \
# ...

# %%
Berry[Berry["Month"] == "Januari"].sort_values(by="Date",ascending=False)
# Out:
#        Month                Date     Profile Name    Channel Content Type  \
# 203  Januari 2019-01-31 19:00:17  Strawberry Spot  INSTAGRAM        image
# 202  Januari 2019-01-31 18:02:06  Strawberry Spot  INSTAGRAM     carousel
# 201  Januari 2019-01-31 15:15:06  Strawberry Spot  INSTAGRAM        image
# 200  Januari 2019-01-31 13:12:58  Strawberry Spot  INSTAGRAM        image
# 199  Januari 2019-01-30 19:00:32  Strawberry Spot  INSTAGRAM        image
# ..       ...                 ...              ...        ...          ...
# 79   Januari 2019-01-01 18:00:44  Strawberry Spot  INSTAGRAM        image
# 78   Januari 2019-01-01 16:00:01  Strawberry Spot  INSTAGRAM        image
# 77   Januari 2019-01-01 14:00:32  Strawberry Spot  INSTAGRAM        image
# 76   Januari 2019-01-01 12:30:38  Strawberry Spot  INSTAGRAM        image
# 75   Januari 2019-01-01 10:30:10  Strawberry Spot  INSTAGRAM        image
#
#       Likes  Comments   Labels  Interactions  Insights - Reach  \
# ...

# %%
Berry[Berry["Month"] == "Februari"].sort_values(by="Date",ascending=False)
# Out:
#         Month                Date     Profile Name    Channel Content Type  \
# 312  Februari 2019-02-28 18:00:17  Strawberry Spot  INSTAGRAM        image
# 311  Februari 2019-02-28 16:00:41  Strawberry Spot  INSTAGRAM        image
# 310  Februari 2019-02-28 14:22:42  Strawberry Spot  INSTAGRAM        image
# 309  Februari 2019-02-28 12:00:20  Strawberry Spot  INSTAGRAM        image
# 308  Februari 2019-02-27 18:00:02  Strawberry Spot  INSTAGRAM        image
# ..        ...                 ...              ...        ...          ...
# 208  Februari 2019-02-02 13:00:48  Strawberry Spot  INSTAGRAM        image
# 207  Februari 2019-02-01 19:30:22  Strawberry Spot  INSTAGRAM        image
# 206  Februari 2019-02-01 19:00:22  Strawberry Spot  INSTAGRAM        image
# 205  Februari 2019-02-01 14:49:28  Strawberry Spot  INSTAGRAM        video
# 204  Februari 2019-02-01 13:58:06  Strawberry Spot  INSTAGRAM        image
#
#       Likes  Comments   Labels  Interactions  Insights - Reach  \
# ...

# %%
Berry[Berry["Month"] == "Maret"].sort_values(by="Date",ascending=False)
# Out:
#      Month                Date     Profile Name    Channel Content Type  \
# 453  Maret 2019-03-31 18:08:15  Strawberry Spot  INSTAGRAM        image
# 452  Maret 2019-03-31 15:29:06  Strawberry Spot  INSTAGRAM        image
# 451  Maret 2019-03-31 12:48:52  Strawberry Spot  INSTAGRAM        video
# 450  Maret 2019-03-30 23:14:09  Strawberry Spot  INSTAGRAM     carousel
# 449  Maret 2019-03-30 22:54:42  Strawberry Spot  INSTAGRAM     carousel
# ..     ...                 ...              ...        ...          ...
# 317  Maret 2019-03-02 12:08:28  Strawberry Spot  INSTAGRAM        image
# 316  Maret 2019-03-01 18:05:16  Strawberry Spot  INSTAGRAM        image
# 315  Maret 2019-03-01 15:59:30  Strawberry Spot  INSTAGRAM        image
# 314  Maret 2019-03-01 14:36:18  Strawberry Spot  INSTAGRAM        image
# 313  Maret 2019-03-01 13:35:16  Strawberry Spot  INSTAGRAM        image
#
#       Likes  Comments   Labels  Interactions  Insights - Reach  \
# ...

# %%
Berry[Berry["Labels"] == "PROMOTED"].sort_values(by="Insights - Reach",ascending=False)
# Out:
#         Month                Date     Profile Name    Channel Content Type  \
# 217  Februari 2019-02-04 10:50:29  Strawberry Spot  INSTAGRAM        image
# 195   Januari 2019-01-29 19:00:10  Strawberry Spot  INSTAGRAM        image
# 174   Januari 2019-01-24 19:30:01  Strawberry Spot  INSTAGRAM        image
# 389     Maret 2019-03-19 19:17:43  Strawberry Spot  INSTAGRAM        image
# 119   Januari 2019-01-11 15:01:03  Strawberry Spot  INSTAGRAM        image
# 415     Maret 2019-03-24 18:00:02  Strawberry Spot  INSTAGRAM        image
#
#        Likes  Comments    Labels  Interactions  Insights - Reach  \
# 217  12474.0     553.0  PROMOTED         13027           92165.0
# 195   4089.0      37.0  PROMOTED          4126           64384.0
# 174   4590.0     309.0  PROMOTED          4899           59950.0
# 389   5862.0     234.0  PROMOTED          6096           59230.0
# 119   4249.0     474.0  PROMOTED          4723           53890.0
# ...

# %%
pd.DataFrame(Berry[Berry["Labels"] == "PROMOTED"].groupby("Content Type")["Insights - Reach"].mean().sort_values(ascending=False))
# Out:
#               Insights - Reach
# Content Type
# image             63209.833333

# %%
Berry[Berry["Labels"] == "PROMOTED"].sort_values(by="Insights - Engagement",ascending=False)
# Out:
#         Month                Date     Profile Name    Channel Content Type  \
# 217  Februari 2019-02-04 10:50:29  Strawberry Spot  INSTAGRAM        image
# 415     Maret 2019-03-24 18:00:02  Strawberry Spot  INSTAGRAM        image
# 389     Maret 2019-03-19 19:17:43  Strawberry Spot  INSTAGRAM        image
# 174   Januari 2019-01-24 19:30:01  Strawberry Spot  INSTAGRAM        image
# 119   Januari 2019-01-11 15:01:03  Strawberry Spot  INSTAGRAM        image
# 195   Januari 2019-01-29 19:00:10  Strawberry Spot  INSTAGRAM        image
#
#        Likes  Comments    Labels  Interactions  Insights - Reach  \
# 217  12474.0     553.0  PROMOTED         13027           92165.0
# 415   7056.0     313.0  PROMOTED          7369           49640.0
# 389   5862.0     234.0  PROMOTED          6096           59230.0
# 174   4590.0     309.0  PROMOTED          4899           59950.0
# 119   4249.0     474.0  PROMOTED          4723           53890.0
# ...

# %%
pd.DataFrame({"Reach vs Impressions (%)": (Berry[Berry["Labels"] == "PROMOTED"].groupby("Content Type")["Insights - Reach"].sum() / Berry[Berry["Labels"] == "PROMOTED"].groupby("Content Type")["Insights - Impressions"].sum()) * 100}).sort_values(by="Reach vs Impressions (%)", ascending=False)
# Out:
#               Reach vs Impressions (%)
# Content Type
# image                        72.804355

# %%
Berry[Berry["Labels"] == "ORGANIC"].sort_values(by="Insights - Saves",ascending=False)
# Out:
#         Month                Date     Profile Name    Channel Content Type  \
# 420     Maret 2019-03-25 19:11:48  Strawberry Spot  INSTAGRAM        video
# 203   Januari 2019-01-31 19:00:17  Strawberry Spot  INSTAGRAM        image
# 452     Maret 2019-03-31 15:29:06  Strawberry Spot  INSTAGRAM        image
# 287  Februari 2019-02-20 18:00:30  Strawberry Spot  INSTAGRAM        image
# 177   Januari 2019-01-25 15:58:24  Strawberry Spot  INSTAGRAM     carousel
# ..        ...                 ...              ...        ...          ...
# 394     Maret 2019-03-20 20:48:00  Strawberry Spot  INSTAGRAM        image
# 401     Maret 2019-03-22 11:00:34  Strawberry Spot  INSTAGRAM        image
# 402     Maret 2019-03-22 13:34:17  Strawberry Spot  INSTAGRAM        image
# 403     Maret 2019-03-22 13:34:31  Strawberry Spot  INSTAGRAM        image
# 258  Februari 2019-02-13 18:01:03  Strawberry Spot  INSTAGRAM        image
#
#       Likes  Comments   Labels  Interactions  Insights - Reach  \
# ...

# %%
Berry[Berry["Labels"] == "PROMOTED"].sort_values(by="Insights - Saves",ascending=False)
# Out:
#         Month                Date     Profile Name    Channel Content Type  \
# 415     Maret 2019-03-24 18:00:02  Strawberry Spot  INSTAGRAM        image
# 195   Januari 2019-01-29 19:00:10  Strawberry Spot  INSTAGRAM        image
# 389     Maret 2019-03-19 19:17:43  Strawberry Spot  INSTAGRAM        image
# 174   Januari 2019-01-24 19:30:01  Strawberry Spot  INSTAGRAM        image
# 217  Februari 2019-02-04 10:50:29  Strawberry Spot  INSTAGRAM        image
# 119   Januari 2019-01-11 15:01:03  Strawberry Spot  INSTAGRAM        image
#
#        Likes  Comments    Labels  Interactions  Insights - Reach  \
# 415   7056.0     313.0  PROMOTED          7369           49640.0
# 195   4089.0      37.0  PROMOTED          4126           64384.0
# 389   5862.0     234.0  PROMOTED          6096           59230.0
# 174   4590.0     309.0  PROMOTED          4899           59950.0
# 217  12474.0     553.0  PROMOTED         13027           92165.0
# ...

# %%
Berry[Berry["Labels"] == "PROMOTED"].sort_values(by="Insights - Engagement",ascending=False)
# Out:
#         Month                Date     Profile Name    Channel Content Type  \
# 217  Februari 2019-02-04 10:50:29  Strawberry Spot  INSTAGRAM        image
# 415     Maret 2019-03-24 18:00:02  Strawberry Spot  INSTAGRAM        image
# 389     Maret 2019-03-19 19:17:43  Strawberry Spot  INSTAGRAM        image
# 174   Januari 2019-01-24 19:30:01  Strawberry Spot  INSTAGRAM        image
# 119   Januari 2019-01-11 15:01:03  Strawberry Spot  INSTAGRAM        image
# 195   Januari 2019-01-29 19:00:10  Strawberry Spot  INSTAGRAM        image
#
#        Likes  Comments    Labels  Interactions  Insights - Reach  \
# 217  12474.0     553.0  PROMOTED         13027           92165.0
# 415   7056.0     313.0  PROMOTED          7369           49640.0
# 389   5862.0     234.0  PROMOTED          6096           59230.0
# 174   4590.0     309.0  PROMOTED          4899           59950.0
# 119   4249.0     474.0  PROMOTED          4723           53890.0
# ...

# %%
pd.DataFrame({"Saves Percentage (%)": (Berry.groupby("Content Type")["Insights - Saves"].sum()/Berry.groupby("Content Type")["Insights - Engagement"].sum()) *100}).sort_values(by="Saves Percentage (%)",ascending=False)
# Out:
#               Saves Percentage (%)
# Content Type
# video                     2.020775
# image                     0.857423
# carousel                  0.652549

# %%
Berry['Date'] = pd.to_datetime(Berry['Date'])
Berry['Hour'] = Berry['Date'].dt.hour

bins = [0, 2, 4, 6, 8, 10, 13, 19, 21, 24]

Berry['Time Slot'] = pd.cut(Berry['Hour'], bins=bins[:-1], labels=['22:00-00:00', '00:00-02:00', '02:00-04:00', '04:00-06:00',
                                                              '06:00-08:00', '11:00-13:00', '19:00-21:00', '21:00-22:00'], right=False)

result_df = Berry.groupby('Time Slot')[['Insights - Reach', 'Insights - Impressions']].mean().round(2)

pd.DataFrame(result_df)
# Out:
# C:\Users\faris\AppData\Local\Temp\ipykernel_32104\2670701888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Berry['Date'] = pd.to_datetime(Berry['Date'])
# C:\Users\faris\AppData\Local\Temp\ipykernel_32104\2670701888.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Berry['Hour'] = Berry['Date'].dt.hour
# C:\Users\faris\AppData\Local\Temp\ipykernel_32104\2670701888.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
